# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\dgrimm\anaconda\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\dgrimm\anaconda\lib\site-packages (from citipy) (0.16)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install openweathermapy
# Out:
# Requirement already satisfied: openweathermapy in c:\users\dgrimm\anaconda\lib\site-packages (0.6.6)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import openweathermapy as ow
from datetime import date
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Variable for todays date
Todays_Date = date.today()
print(Todays_Date)
# Out:
# 2018-10-26

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base Url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=

# %%
# Lists for data
CityName = []
Cloudiness = []
Country = []
Date = []
Humdity = []
Lat = []
Lng = []
MaxTemp = []
MinTemp = []
WindSpeed = []

# Counter to get at least 500 records 
record = 1 
record_counter = 500

# Processing data for each city and adding to lists
for city in cities:
    try: 
        print(f"Processing record {record} of Set {record} | {city}")
        weather_response = requests.get(query_url + city).json()
        CityName.append(weather_response["name"])
        Cloudiness.append(weather_response["clouds"]["all"])
        Country.append(weather_response["sys"]["country"])
        Date.append(weather_response["dt"])
        Humdity.append(weather_response["main"]["humidity"])
        Lat.append(weather_response["coord"]["lat"])
        Lng.append(weather_response["coord"]["lon"])
        MaxTemp.append(weather_response["main"]["temp_max"])
        MinTemp.append(weather_response["main"]["temp_min"])
        WindSpeed.append(weather_response["wind"]["speed"])
    except (KeyError, IndexError):
        print("City isn't available")
    
    # Need at least 500 so add more 15% of 500... probably better way of doing this
    finally:
        if record < (record_counter*1.15):
              record = record + 1
        else:
            break
# Out:
# Processing record 1 of Set 1 | hithadhoo
# Processing record 2 of Set 2 | tsihombe
# City isn't available
# Processing record 3 of Set 3 | baykit
# Processing record 4 of Set 4 | henties bay
# Processing record 5 of Set 5 | jamestown
# Processing record 6 of Set 6 | hilo
# Processing record 7 of Set 7 | cidreira
# Processing record 8 of Set 8 | basco
# Processing record 9 of Set 9 | rikitea
# Processing record 10 of Set 10 | saint-philippe
# Processing record 11 of Set 11 | guadix
# Processing record 12 of Set 12 | raudeberg
# Processing record 13 of Set 13 | halifax
# Processing record 14 of Set 14 | butaritari
# Processing record 15 of Set 15 | ushuaia
# Processing record 16 of Set 16 | aksarka
# Processing record 17 of Set 17 | illoqqortoormiut
# City isn't available
# Processing record 18 of Set 18 | nabire
# Processing record 19 of Set 19 | saint-malo
# Processing record 20 of Set 20 | busselton
# Processing record 21 of Set 21 | acapulco
# Processing record 22 of Set 22 | riviere-au-renard
# Processing record 23 of Set 23 | heinsberg
# Processing record 24 of Set 24 | ribeira brava
# Processing record 25 of Set 25 | lakes entrance
# Processing record 26 of Set 26 | berberati
# Processing record 27 of Set 27 | lensk
# Processing record 28 of Set 28 | grindavik
# Processing record 29 of Set 29 | amderma
# City isn't available
# Processing record 30 of Set 30 | lasa
# Processing record 31 of Set 31 | albany
# Processing record 32 of Set 32 | nikolskoye
# Processing record 33 of Set 33 | atuona
# Processing record 34 of Set 34 | guerrero negro
# Processing record 35 of Set 35 | vaitupu
# City isn't available
# Processing record 36 of Set 36 | kaitangata
# Processing record 37 of Set 37 | havoysund
# Processing record 38 of Set 38 | brownwood
# Processing record 39 of Set 39 | mahebourg
# Processing record 40 of Set 40 | trairi
# Processing record 41 of Set 41 | punta arenas
# Processing record 42 of Set 42 | jalu
# Processing record 43 of Set 43 | grand river south east
# City isn't available
# Processing record 44 of Set 44 | attawapiskat
# City isn't available
# Processing record 45 of Set 45 | port alfred
# Processing record 46 of Set 46 | cabo san lucas
# Processing record 47 of Set 47 | puerto ayora
# Processing record 48 of Set 48 | teocaltiche
# Processing record 49 of Set 49 | qaanaaq
# Processing record 50 of Set 50 | komsomolskiy
# Processing record 51 of Set 51 | kapaa
# Processing record 52 of Set 52 | georgetown
# Processing record 53 of Set 53 | nishihara
# Processing record 54 of Set 54 | vaini
# Processing record 55 of Set 55 | charlestown
# Processing record 56 of Set 56 | chokurdakh
# Processing record 57 of Set 57 | kuching
# Processing record 58 of Set 58 | quatre cocos
# Processing record 59 of Set 59 | yellowknife
# Processing record 60 of Set 60 | kruisfontein
# Processing record 61 of Set 61 | cayenne
# Processing record 62 of Set 62 | la ronge
# Processing record 63 of Set 63 | port elizabeth
# Processing record 64 of Set 64 | saint george
# Processing record 65 of Set 65 | yulara
# Processing record 66 of Set 66 | tailai
# Processing record 67 of Set 67 | asau
# City isn't available
# Processing record 68 of Set 68 | cherskiy
# Processing record 69 of Set 69 | flin flon
# Processing record 70 of Set 70 | tomatlan
# Processing record 71 of Set 71 | husavik
# Processing record 72 of Set 72 | yumen
# Processing record 73 of Set 73 | san patricio
# Processing record 74 of Set 74 | cape town
# Processing record 75 of Set 75 | jiuquan
# Processing record 76 of Set 76 | new norfolk
# Processing record 77 of Set 77 | vikindu
# Processing record 78 of Set 78 | belushya guba
# City isn't available
# Processing record 79 of Set 79 | haines junction
# Processing record 80 of Set 80 | saint-pierre
# Processing record 81 of Set 81 | diego de almagro
# Processing record 82 of Set 82 | olafsvik
# City isn't available
# Processing record 83 of Set 83 | caravelas
# Processing record 84 of Set 84 | werda
# Processing record 85 of Set 85 | katsuura
# Processing record 86 of Set 86 | hambantota
# Processing record 87 of Set 87 | mataura
# Processing record 88 of Set 88 | acari
# Processing record 89 of Set 89 | bredasdorp
# Processing record 90 of Set 90 | wamba
# Processing record 91 of Set 91 | ler
# Processing record 92 of Set 92 | castro
# Processing record 93 of Set 93 | vila
# Processing record 94 of Set 94 | thompson
# Processing record 95 of Set 95 | saskylakh
# Processing record 96 of Set 96 | hobart
# Processing record 97 of Set 97 | severo-kurilsk
# Processing record 98 of Set 98 | longyearbyen
# Processing record 99 of Set 99 | brae
# Processing record 100 of Set 100 | bol
# Processing record 101 of Set 101 | port hardy
# Processing record 102 of Set 102 | dhidhdhoo
# Processing record 103 of Set 103 | jaisalmer
# Processing record 104 of Set 104 | hermanus
# Processing record 105 of Set 105 | omboue
# Processing record 106 of Set 106 | skibbereen
# Processing record 107 of Set 107 | victoria
# Processing record 108 of Set 108 | souillac
# Processing record 109 of Set 109 | tura
# Processing record 110 of Set 110 | mar del plata
# Processing record 111 of Set 111 | urubicha
# Processing record 112 of Set 112 | bonnyville
# Processing record 113 of Set 113 | nome
# Processing record 114 of Set 114 | cantanhede
# Processing record 115 of Set 115 | kingaroy
# Processing record 116 of Set 116 | chicama
# Processing record 117 of Set 117 | port augusta
# Processing record 118 of Set 118 | barrow
# Processing record 119 of Set 119 | sitka
# Processing record 120 of Set 120 | lorengau
# Processing record 121 of Set 121 | dunedin
# Processing record 122 of Set 122 | khatanga
# Processing record 123 of Set 123 | lolua
# City isn't available
# Processing record 124 of Set 124 | sao filipe
# Processing record 125 of Set 125 | ribeira grande
# Processing record 126 of Set 126 | ust-koksa
# Processing record 127 of Set 127 | zhezkazgan
# Processing record 128 of Set 128 | kanigoro
# Processing record 129 of Set 129 | gogrial
# City isn't available
# Processing record 130 of Set 130 | sao joao da barra
# Processing record 131 of Set 131 | saldanha
# Processing record 132 of Set 132 | malakal
# City isn't available
# Processing record 133 of Set 133 | tasiilaq
# Processing record 134 of Set 134 | vila do maio
# Processing record 135 of Set 135 | taolanaro
# City isn't available
# Processing record 136 of Set 136 | paamiut
# Processing record 137 of Set 137 | mahibadhoo
# Processing record 138 of Set 138 | samusu
# City isn't available
# Processing record 139 of Set 139 | bajil
# Processing record 140 of Set 140 | bluff
# Processing record 141 of Set 141 | ponta do sol
# Processing record 142 of Set 142 | egvekinot
# Processing record 143 of Set 143 | shieli
# Processing record 144 of Set 144 | bend
# Processing record 145 of Set 145 | faanui
# Processing record 146 of Set 146 | puerto narino
# Processing record 147 of Set 147 | karwar
# Processing record 148 of Set 148 | vrangel
# Processing record 149 of Set 149 | srednekolymsk
# Processing record 150 of Set 150 | vengerovo
# Processing record 151 of Set 151 | yenagoa
# Processing record 152 of Set 152 | fairbanks
# Processing record 153 of Set 153 | san ramon de la nueva oran
# Processing record 154 of Set 154 | constitucion
# Processing record 155 of Set 155 | libohove
# Processing record 156 of Set 156 | tuktoyaktuk
# Processing record 157 of Set 157 | norman wells
# Processing record 158 of Set 158 | yarada
# Processing record 159 of Set 159 | bumba
# Processing record 160 of Set 160 | broome
# Processing record 161 of Set 161 | batagay-alyta
# Processing record 162 of Set 162 | scarborough
# Processing record 163 of Set 163 | shepsi
# Processing record 164 of Set 164 | kuryk
# Processing record 165 of Set 165 | pasni
# Processing record 166 of Set 166 | carnarvon
# Processing record 167 of Set 167 | tautira
# Processing record 168 of Set 168 | wanaka
# Processing record 169 of Set 169 | tiarei
# Processing record 170 of Set 170 | dingle
# Processing record 171 of Set 171 | mandalgovi
# Processing record 172 of Set 172 | tarut
# Processing record 173 of Set 173 | hervey bay
# Processing record 174 of Set 174 | saurimo
# Processing record 175 of Set 175 | petropavlovsk-kamchatskiy
# Processing record 176 of Set 176 | torbay
# Processing record 177 of Set 177 | iqaluit
# Processing record 178 of Set 178 | dwarka
# Processing record 179 of Set 179 | itarema
# Processing record 180 of Set 180 | atambua
# Processing record 181 of Set 181 | nizhneyansk
# City isn't available
# Processing record 182 of Set 182 | vostok
# Processing record 183 of Set 183 | lata
# Processing record 184 of Set 184 | east london
# Processing record 185 of Set 185 | road town
# Processing record 186 of Set 186 | cuamba
# Processing record 187 of Set 187 | buraydah
# Processing record 188 of Set 188 | clyde river
# Processing record 189 of Set 189 | etchoropo
# Processing record 190 of Set 190 | avarua
# Processing record 191 of Set 191 | salyan
# Processing record 192 of Set 192 | lebu
# Processing record 193 of Set 193 | ilulissat
# Processing record 194 of Set 194 | namatanai
# Processing record 195 of Set 195 | shakawe
# Processing record 196 of Set 196 | dikson
# Processing record 197 of Set 197 | yar-sale
# Processing record 198 of Set 198 | marawi
# Processing record 199 of Set 199 | cortez
# Processing record 200 of Set 200 | san cristobal
# Processing record 201 of Set 201 | ahipara
# Processing record 202 of Set 202 | provideniya
# Processing record 203 of Set 203 | erenhot
# Processing record 204 of Set 204 | nikki
# Processing record 205 of Set 205 | nata
# Processing record 206 of Set 206 | sarajevo
# Processing record 207 of Set 207 | pontian kecil
# Processing record 208 of Set 208 | vardo
# Processing record 209 of Set 209 | san carlos de bariloche
# Processing record 210 of Set 210 | druzhba
# Processing record 211 of Set 211 | pevek
# Processing record 212 of Set 212 | taoudenni
# Processing record 213 of Set 213 | goryachiy klyuch
# Processing record 214 of Set 214 | beringovskiy
# Processing record 215 of Set 215 | banjar
# Processing record 216 of Set 216 | ilinsko-podomskoye
# City isn't available
# Processing record 217 of Set 217 | svetlyy
# City isn't available
# Processing record 218 of Set 218 | eenhana
# Processing record 219 of Set 219 | burica
# City isn't available
# Processing record 220 of Set 220 | berlevag
# Processing record 221 of Set 221 | farsund
# Processing record 222 of Set 222 | toamasina
# Processing record 223 of Set 223 | arraial do cabo
# Processing record 224 of Set 224 | vanimo
# Processing record 225 of Set 225 | sakaiminato
# Processing record 226 of Set 226 | morondava
# Processing record 227 of Set 227 | braco do norte
# Processing record 228 of Set 228 | ituni
# City isn't available
# Processing record 229 of Set 229 | shadegan
# Processing record 230 of Set 230 | ankang
# Processing record 231 of Set 231 | port lincoln
# Processing record 232 of Set 232 | bahia blanca
# Processing record 233 of Set 233 | martin
# Processing record 234 of Set 234 | lithakia
# Processing record 235 of Set 235 | verkhniye kigi
# Processing record 236 of Set 236 | tumbagaan
# Processing record 237 of Set 237 | salgado
# Processing record 238 of Set 238 | yatou
# Processing record 239 of Set 239 | indaiatuba
# Processing record 240 of Set 240 | leshukonskoye
# Processing record 241 of Set 241 | hualmay
# Processing record 242 of Set 242 | kamaishi
# Processing record 243 of Set 243 | bhag
# Processing record 244 of Set 244 | gravelbourg
# Processing record 245 of Set 245 | santa maria
# Processing record 246 of Set 246 | klaksvik
# Processing record 247 of Set 247 | bengkulu
# City isn't available
# Processing record 248 of Set 248 | kralendijk
# Processing record 249 of Set 249 | ishigaki
# Processing record 250 of Set 250 | takoradi
# Processing record 251 of Set 251 | hatillo
# Processing record 252 of Set 252 | broken hill
# Processing record 253 of Set 253 | port-gentil
# Processing record 254 of Set 254 | mozarlandia
# Processing record 255 of Set 255 | lagoa
# Processing record 256 of Set 256 | pyay
# Processing record 257 of Set 257 | karamay
# City isn't available
# Processing record 258 of Set 258 | opuwo
# Processing record 259 of Set 259 | tuatapere
# Processing record 260 of Set 260 | andevoranto
# City isn't available
# Processing record 261 of Set 261 | farah
# Processing record 262 of Set 262 | puerto carreno
# Processing record 263 of Set 263 | znamenskoye
# Processing record 264 of Set 264 | dong xoai
# Processing record 265 of Set 265 | vao
# Processing record 266 of Set 266 | saint anthony
# Processing record 267 of Set 267 | ulladulla
# Processing record 268 of Set 268 | nemuro
# Processing record 269 of Set 269 | esperance
# Processing record 270 of Set 270 | axim
# Processing record 271 of Set 271 | sisimiut
# Processing record 272 of Set 272 | pisco
# Processing record 273 of Set 273 | bethel
# Processing record 274 of Set 274 | biryusinsk
# Processing record 275 of Set 275 | mahaicony
# City isn't available
# Processing record 276 of Set 276 | barentsburg
# City isn't available
# Processing record 277 of Set 277 | kysyl-syr
# Processing record 278 of Set 278 | santa fe do sul
# Processing record 279 of Set 279 | half moon bay
# Processing record 280 of Set 280 | daru
# Processing record 281 of Set 281 | darnah
# Processing record 282 of Set 282 | vidim
# Processing record 283 of Set 283 | rio gallegos
# Processing record 284 of Set 284 | chanika
# Processing record 285 of Set 285 | mananjary
# Processing record 286 of Set 286 | ambilobe
# Processing record 287 of Set 287 | ewa beach
# Processing record 288 of Set 288 | bilibino
# Processing record 289 of Set 289 | choix
# Processing record 290 of Set 290 | kavaratti
# Processing record 291 of Set 291 | dudinka
# Processing record 292 of Set 292 | auki
# Processing record 293 of Set 293 | diamantino
# Processing record 294 of Set 294 | dzhusaly
# City isn't available
# Processing record 295 of Set 295 | benguela
# Processing record 296 of Set 296 | seoul
# Processing record 297 of Set 297 | ostrovnoy
# Processing record 298 of Set 298 | ondorhaan
# City isn't available
# Processing record 299 of Set 299 | poum
# Processing record 300 of Set 300 | hofn
# Processing record 301 of Set 301 | alofi
# Processing record 302 of Set 302 | biak
# Processing record 303 of Set 303 | acarau
# City isn't available
# Processing record 304 of Set 304 | nehe
# Processing record 305 of Set 305 | aflu
# City isn't available
# Processing record 306 of Set 306 | davidson
# Processing record 307 of Set 307 | villarrobledo
# Processing record 308 of Set 308 | coquimbo
# Processing record 309 of Set 309 | teguise
# Processing record 310 of Set 310 | santa cruz de la palma
# Processing record 311 of Set 311 | ambodifototra
# City isn't available
# Processing record 312 of Set 312 | skjervoy
# Processing record 313 of Set 313 | batemans bay
# Processing record 314 of Set 314 | nantucket
# Processing record 315 of Set 315 | rock sound
# Processing record 316 of Set 316 | newport
# Processing record 317 of Set 317 | kodiak
# Processing record 318 of Set 318 | goderich
# Processing record 319 of Set 319 | hasaki
# Processing record 320 of Set 320 | flinders
# Processing record 321 of Set 321 | punta alta
# Processing record 322 of Set 322 | ancud
# Processing record 323 of Set 323 | kulhudhuffushi
# Processing record 324 of Set 324 | dolores
# Processing record 325 of Set 325 | price
# Processing record 326 of Set 326 | sioux lookout
# Processing record 327 of Set 327 | uddevalla
# Processing record 328 of Set 328 | sarkand
# Processing record 329 of Set 329 | kudahuvadhoo
# Processing record 330 of Set 330 | bonfim
# Processing record 331 of Set 331 | homer
# Processing record 332 of Set 332 | afmadu
# City isn't available
# Processing record 333 of Set 333 | belmonte
# Processing record 334 of Set 334 | vuktyl
# Processing record 335 of Set 335 | murgab
# Processing record 336 of Set 336 | canmore
# Processing record 337 of Set 337 | khuzdar
# Processing record 338 of Set 338 | leningradskiy
# Processing record 339 of Set 339 | bayanday
# Processing record 340 of Set 340 | pandan
# Processing record 341 of Set 341 | peleduy
# Processing record 342 of Set 342 | pangnirtung
# Processing record 343 of Set 343 | sobrance
# Processing record 344 of Set 344 | pouebo
# Processing record 345 of Set 345 | chuy
# Processing record 346 of Set 346 | vallenar
# Processing record 347 of Set 347 | hamilton
# Processing record 348 of Set 348 | kavieng
# Processing record 349 of Set 349 | huron
# Processing record 350 of Set 350 | bandar-e lengeh
# Processing record 351 of Set 351 | muzhi
# Processing record 352 of Set 352 | bambous virieux
# Processing record 353 of Set 353 | alpena
# Processing record 354 of Set 354 | yeppoon
# Processing record 355 of Set 355 | zhuanghe
# Processing record 356 of Set 356 | codrington
# Processing record 357 of Set 357 | banda aceh
# Processing record 358 of Set 358 | port shepstone
# Processing record 359 of Set 359 | verkhoyansk
# Processing record 360 of Set 360 | isangel
# Processing record 361 of Set 361 | bubaque
# Processing record 362 of Set 362 | waingapu
# Processing record 363 of Set 363 | garissa
# Processing record 364 of Set 364 | touros
# Processing record 365 of Set 365 | kedrovyy
# Processing record 366 of Set 366 | polczyn-zdroj
# Processing record 367 of Set 367 | pangody
# Processing record 368 of Set 368 | guiyang
# Processing record 369 of Set 369 | upernavik
# Processing record 370 of Set 370 | pauini
# Processing record 371 of Set 371 | puerto cabezas
# Processing record 372 of Set 372 | petrovskoye
# Processing record 373 of Set 373 | novyy urengoy
# Processing record 374 of Set 374 | geraldton
# Processing record 375 of Set 375 | filingue
# Processing record 376 of Set 376 | serebryansk
# Processing record 377 of Set 377 | andenes
# City isn't available
# Processing record 378 of Set 378 | mehamn
# Processing record 379 of Set 379 | peniche
# Processing record 380 of Set 380 | aklavik
# Processing record 381 of Set 381 | hami
# Processing record 382 of Set 382 | buchanan
# Processing record 383 of Set 383 | salalah
# Processing record 384 of Set 384 | horodnytsya
# Processing record 385 of Set 385 | rincon
# Processing record 386 of Set 386 | oum hadjer
# Processing record 387 of Set 387 | airai
# Processing record 388 of Set 388 | geretsried
# Processing record 389 of Set 389 | muroto
# Processing record 390 of Set 390 | ust-kamchatsk
# City isn't available
# Processing record 391 of Set 391 | umm lajj
# Processing record 392 of Set 392 | sainte-anne-des-monts
# Processing record 393 of Set 393 | havre-saint-pierre
# Processing record 394 of Set 394 | leh
# Processing record 395 of Set 395 | camacupa
# Processing record 396 of Set 396 | le vauclin
# Processing record 397 of Set 397 | lazi
# Processing record 398 of Set 398 | north branch
# Processing record 399 of Set 399 | safaga
# City isn't available
# Processing record 400 of Set 400 | makakilo city
# Processing record 401 of Set 401 | falealupo
# City isn't available
# Processing record 402 of Set 402 | kota kinabalu
# Processing record 403 of Set 403 | mulege
# Processing record 404 of Set 404 | benghazi
# Processing record 405 of Set 405 | saleaula
# City isn't available
# Processing record 406 of Set 406 | bolkhov
# Processing record 407 of Set 407 | mana
# Processing record 408 of Set 408 | catabola
# Processing record 409 of Set 409 | kahului
# Processing record 410 of Set 410 | charters towers
# Processing record 411 of Set 411 | impfondo
# Processing record 412 of Set 412 | cabrobo
# Processing record 413 of Set 413 | oparino
# Processing record 414 of Set 414 | santa rosa
# Processing record 415 of Set 415 | sur
# Processing record 416 of Set 416 | yialos
# City isn't available
# Processing record 417 of Set 417 | marsh harbour
# Processing record 418 of Set 418 | sosnovo-ozerskoye
# Processing record 419 of Set 419 | umzimvubu
# City isn't available
# Processing record 420 of Set 420 | sentyabrskiy
# City isn't available
# Processing record 421 of Set 421 | lubao
# Processing record 422 of Set 422 | kudat
# Processing record 423 of Set 423 | lazaro cardenas
# Processing record 424 of Set 424 | jiamusi
# Processing record 425 of Set 425 | kabanjahe
# Processing record 426 of Set 426 | gusinoye ozero
# Processing record 427 of Set 427 | san jeronimo
# Processing record 428 of Set 428 | alice springs
# Processing record 429 of Set 429 | tabou
# Processing record 430 of Set 430 | yeniseysk
# Processing record 431 of Set 431 | shihezi
# Processing record 432 of Set 432 | toliary
# City isn't available
# Processing record 433 of Set 433 | nicoya
# Processing record 434 of Set 434 | mattru
# Processing record 435 of Set 435 | key west
# Processing record 436 of Set 436 | melbourne
# Processing record 437 of Set 437 | pastavy
# Processing record 438 of Set 438 | kununurra
# Processing record 439 of Set 439 | sinop
# Processing record 440 of Set 440 | novorudnyy
# Processing record 441 of Set 441 | bongandanga
# Processing record 442 of Set 442 | sakhon nakhon
# City isn't available
# Processing record 443 of Set 443 | murray bridge
# Processing record 444 of Set 444 | santa vitoria do palmar
# Processing record 445 of Set 445 | juegang
# Processing record 446 of Set 446 | bunia
# Processing record 447 of Set 447 | khormuj
# City isn't available
# Processing record 448 of Set 448 | faya
# Processing record 449 of Set 449 | launceston
# Processing record 450 of Set 450 | sorgun
# Processing record 451 of Set 451 | lac du bonnet
# Processing record 452 of Set 452 | marcona
# City isn't available
# Processing record 453 of Set 453 | le port
# Processing record 454 of Set 454 | mys shmidta
# City isn't available
# Processing record 455 of Set 455 | mataundh
# Processing record 456 of Set 456 | valparaiso
# Processing record 457 of Set 457 | miquelon
# Processing record 458 of Set 458 | lichinga
# Processing record 459 of Set 459 | tahta
# City isn't available
# Processing record 460 of Set 460 | obo
# Processing record 461 of Set 461 | kasongo-lunda
# Processing record 462 of Set 462 | san carlos
# Processing record 463 of Set 463 | dalhousie
# Processing record 464 of Set 464 | jepara
# Processing record 465 of Set 465 | betsiamites
# Processing record 466 of Set 466 | douglas
# Processing record 467 of Set 467 | antalaha
# Processing record 468 of Set 468 | aguimes
# Processing record 469 of Set 469 | dangtu
# Processing record 470 of Set 470 | rorvik
# Processing record 471 of Set 471 | jega
# Processing record 472 of Set 472 | williston
# Processing record 473 of Set 473 | port blair
# Processing record 474 of Set 474 | portland
# Processing record 475 of Set 475 | atar
# Processing record 476 of Set 476 | meyungs
# City isn't available
# Processing record 477 of Set 477 | songadh
# Processing record 478 of Set 478 | muyezerskiy
# Processing record 479 of Set 479 | barawe
# City isn't available
# Processing record 480 of Set 480 | riyadh
# Processing record 481 of Set 481 | sistranda
# Processing record 482 of Set 482 | harper
# Processing record 483 of Set 483 | nuuk
# Processing record 484 of Set 484 | mumford
# Processing record 485 of Set 485 | mareeba
# Processing record 486 of Set 486 | neuquen
# Processing record 487 of Set 487 | opunake
# Processing record 488 of Set 488 | nadvoitsy
# Processing record 489 of Set 489 | olinda
# Processing record 490 of Set 490 | kenora
# Processing record 491 of Set 491 | juifang
# City isn't available
# Processing record 492 of Set 492 | tarata
# Processing record 493 of Set 493 | kologriv
# Processing record 494 of Set 494 | formoso do araguaia
# City isn't available
# Processing record 495 of Set 495 | verkh-usugli
# Processing record 496 of Set 496 | muravlenko
# Processing record 497 of Set 497 | guiren
# Processing record 498 of Set 498 | vila velha
# Processing record 499 of Set 499 | ruteng
# Processing record 500 of Set 500 | kajaani
# Processing record 501 of Set 501 | new glasgow
# Processing record 502 of Set 502 | viedma
# Processing record 503 of Set 503 | porbandar
# Processing record 504 of Set 504 | san pedro
# Processing record 505 of Set 505 | pombas
# Processing record 506 of Set 506 | guia de isora
# Processing record 507 of Set 507 | labuhan
# Processing record 508 of Set 508 | marsa matruh
# Processing record 509 of Set 509 | coahuayana
# Processing record 510 of Set 510 | moranbah
# Processing record 511 of Set 511 | filiatra
# Processing record 512 of Set 512 | whitecourt
# Processing record 513 of Set 513 | saint-augustin
# Processing record 514 of Set 514 | palabuhanratu
# City isn't available
# Processing record 515 of Set 515 | bombo
# Processing record 516 of Set 516 | fortuna
# Processing record 517 of Set 517 | chapais
# Processing record 518 of Set 518 | marzuq
# Processing record 519 of Set 519 | ust-nera
# Processing record 520 of Set 520 | tilichiki
# Processing record 521 of Set 521 | waipawa
# Processing record 522 of Set 522 | muros
# Processing record 523 of Set 523 | gobabis
# Processing record 524 of Set 524 | zachagansk
# City isn't available
# Processing record 525 of Set 525 | bonavista
# Processing record 526 of Set 526 | palu
# Processing record 527 of Set 527 | athabasca
# Processing record 528 of Set 528 | oneonta
# Processing record 529 of Set 529 | angoche
# Processing record 530 of Set 530 | duku
# Processing record 531 of Set 531 | auray
# Processing record 532 of Set 532 | nasturelu
# Processing record 533 of Set 533 | lieksa
# Processing record 534 of Set 534 | sao jose da coroa grande
# Processing record 535 of Set 535 | namibe
# Processing record 536 of Set 536 | kushima
# Processing record 537 of Set 537 | maniitsoq
# Processing record 538 of Set 538 | ambon
# Processing record 539 of Set 539 | mahajanga
# Processing record 540 of Set 540 | chengmai
# City isn't available
# Processing record 541 of Set 541 | sinnamary
# Processing record 542 of Set 542 | aasiaat
# Processing record 543 of Set 543 | borba
# Processing record 544 of Set 544 | pinega
# Processing record 545 of Set 545 | lhokseumawe
# Processing record 546 of Set 546 | tateyama
# Processing record 547 of Set 547 | barcelos
# Processing record 548 of Set 548 | cody
# Processing record 549 of Set 549 | beloha
# Processing record 550 of Set 550 | la rioja
# Processing record 551 of Set 551 | thunder bay
# Processing record 552 of Set 552 | zambezi
# Processing record 553 of Set 553 | siguiri
# Processing record 554 of Set 554 | labutta
# City isn't available
# Processing record 555 of Set 555 | pontes e lacerda
# Processing record 556 of Set 556 | makaleng
# Processing record 557 of Set 557 | luis correia
# Processing record 558 of Set 558 | tombouctou
# Processing record 559 of Set 559 | cacequi
# Processing record 560 of Set 560 | misratah
# Processing record 561 of Set 561 | rocha
# Processing record 562 of Set 562 | halalo
# City isn't available
# Processing record 563 of Set 563 | rungata
# City isn't available
# Processing record 564 of Set 564 | muscat
# Processing record 565 of Set 565 | petrozavodsk
# Processing record 566 of Set 566 | mullaitivu
# City isn't available
# Processing record 567 of Set 567 | severobaykalsk
# Processing record 568 of Set 568 | san policarpo
# Processing record 569 of Set 569 | nakusp
# Processing record 570 of Set 570 | hay river
# Processing record 571 of Set 571 | kungurtug
# Processing record 572 of Set 572 | mount isa
# Processing record 573 of Set 573 | adrar
# Processing record 574 of Set 574 | aden
# Processing record 575 of Set 575 | san pedro del pinatar

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe and counting records to make sure they match
weather = {"City" : CityName, "Cloudiness" : Cloudiness, "Country" : Country, "Date" : Date, "Humidity" : Humdity, 
           "Lat" : Lat, "Lng" : Lng, "Max Temp" : MaxTemp, "Wind Speed" : WindSpeed}

weather_df = pd.DataFrame(weather)
weather_df.count()
# Out:
# City          520
# Cloudiness    520
# Country       520
# Date          520
# Humidity      520
# Lat           520
# Lng           520
# Max Temp      520
# Wind Speed    520
# dtype: int64

# %%
# Printing summary of dataframe
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Hithadhoo          88      MV  1540549426       100  -0.60   73.08
# 1       Baykit          88      RU  1540549426        83  61.68   96.39
# 2  Henties Bay           0      NA  1540549427        71 -22.12   14.28
# 3    Jamestown           0      AU  1540549427        28 -33.21  138.60
# 4         Hilo          40      US  1540547760        94  19.71 -155.08
#
#    Max Temp  Wind Speed
# 0     78.88       13.47
# 1     30.64        4.63
# 2     78.84        4.41
# 3     69.25        5.97
# 4     73.40        6.93

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Titles, grid and labels
plt.title(f"City Latitue vs. Max Temp ({Todays_Date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(True)

# Creating Scatterplots
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], label = "Rural", marker="o", 
            edgecolor="black", linewidth=1, color="lightblue")

# Saving file
plt.savefig("../Images/TempScatter.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Titles, grid and labels
plt.title(f"City Latitude vs. Max Humidity ({Todays_Date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Creating Scatterplots
plt.scatter(weather_df["Lat"], weather_df["Humidity"], label = "Rural", marker="o", 
            edgecolor="black", linewidth=1, color="lightblue")

# Saving file
plt.savefig("../Images/Humidity_Scatter.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Titles, grid and labels
plt.title(f"City Latitue vs. Cloudiness ({Todays_Date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Creating Scatterplots
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], label = "Rural", marker="o", 
            edgecolor="black", linewidth=1, color="lightblue")

# Saving file
plt.savefig("../Images/Cloudiness_Scatter.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Titles, grid and labels
plt.title(f"City Latitue vs. Wind Speed ({Todays_Date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Creating Scatterplots
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], label = "Rural", marker="o", 
            edgecolor="black", linewidth=1, color="lightblue")

# Saving file
plt.savefig("../Images/Wind_Scatter.png")
